# %%
import cerf
import pandas as pd
import geopandas as gpd

import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('example_cerf_output.csv')

df.head()
# Out:
#   region_name  tech_id             tech_name  unit_size_mw       xcoord  \
# 0     alabama        4  coal_conv_pul_wo_ccs         600.0  744947.1645
# 1     alabama        4  coal_conv_pul_wo_ccs         600.0  790947.1645
# 2     alabama        4  coal_conv_pul_wo_ccs         600.0  854947.1645
# 3     alabama        4  coal_conv_pul_wo_ccs         600.0  957947.1645
# 4     alabama        4  coal_conv_pul_wo_ccs         600.0  774947.1645
#
#         ycoord    index  buffer_in_km  sited_year  retirement_year  ...  \
# 0 -364565.2005  9267132             5        2010             2070  ...
# 1 -386565.2005  9370424             5        2010             2070  ...
# 2 -470565.2005  9764700             5        2010             2070  ...
# 3 -376565.2005  9323661             5        2010             2070  ...
# 4 -473565.2005  9778699             5        2010             2070  ...
#
#    carbon_capture_rate_fraction  fuel_co2_content_tons_per_btu  \
# ...

# %%
# print the titles/info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   region_name                            8369 non-null   object
#  1   tech_id                                8369 non-null   int64
#  2   tech_name                              8369 non-null   object
#  3   unit_size_mw                           8369 non-null   float64
#  4   xcoord                                 8369 non-null   float64
#  5   ycoord                                 8369 non-null   float64
#  6   index                                  8369 non-null   int64
#  7   buffer_in_km                           8369 non-null   int64
#  8   sited_year                             8369 non-null   int64
#  9   retirement_year                        8369 non-null   int64
# ...

# %%
new_df = df.loc[(df["sited_year"] == 2030)].copy()

new_df
# Out:
#      region_name  tech_id             tech_name  unit_size_mw        xcoord  \
# 1553     alabama        4  coal_conv_pul_wo_ccs         600.0  8.569472e+05
# 1554     alabama        4  coal_conv_pul_wo_ccs         600.0  8.159472e+05
# 1555     alabama        4  coal_conv_pul_wo_ccs         600.0  9.789472e+05
# 1556     alabama        4  coal_conv_pul_wo_ccs         600.0  8.479472e+05
# 1557     alabama        4  coal_conv_pul_wo_ccs         600.0  7.929472e+05
# ...          ...      ...                   ...           ...           ...
# 3911     wyoming       17     solar_pv_non_dist          80.0 -1.123053e+06
# 3912     wyoming       18          wind_onshore         251.0 -7.150528e+05
# 3913     wyoming       18          wind_onshore         251.0 -7.540528e+05
# 3914     wyoming       18          wind_onshore         251.0 -1.240053e+06
# 3915     wyoming       18          wind_onshore         251.0 -1.196053e+06
#
# ...

# %% [markdown]
# ### Converting our coordinate reference system
#
# We need to first get our `xcoord` and `ycoord` fields associated with a coordinate reference system so that they can be transformed into the coordinate system that ploty is expecting.
#
# The CERF data is produced using the USA Contiguous Albers Equal Area Conic projected coordinate system in meters. GeoPandas allows you to set these once a geometry field has been made.
#
# We need to build our geometry field from our CERF coordinate values using:
# `gpd.points_from_xy(new_df["xcoord"], new_df["ycoord"])`
#
# We are also telling the geopandas dataframe that we know that data is in USA Contiguous Albers Equal Area Conic and we are going to give it a shortcut known as an EPSG code to get that set up for us.  You can see more about the EPSG code if you are interested here:  https://epsg.io/102003

# %%
gdf = gpd.GeoDataFrame(new_df, 
                       geometry=gpd.points_from_xy(new_df["xcoord"], new_df["ycoord"]),
                       crs="ESRI:102003")

# let's take a look at our geometry field
gdf.geometry
# Out:
# 1553     POINT (856947.164 -638565.201)
# 1554     POINT (815947.164 -360565.200)
# 1555     POINT (978947.164 -492565.200)
# 1556     POINT (847947.164 -674565.201)
# 1557     POINT (792947.164 -462565.200)
#                      ...
# 3911    POINT (-1123052.836 662434.799)
# 3912     POINT (-715052.836 568434.799)
# 3913     POINT (-754052.836 818434.799)
# 3914    POINT (-1240052.836 523434.800)
# 3915    POINT (-1196052.836 572434.799)
# Name: geometry, Length: 2363, dtype: geometry

# %% [markdown]
# Our next step is to transform, or reproject, our coordinate reference system from CERF's native projection to a geographic coordinate system (one that has latitude and longitude values rather than x, y coordinates) that Plotly expectes.
#
# Again, we use our handy EPSG code to tell it we want the data in WGS 84 (https://epsg.io/4326).
#
# We use the `inplace` setting meaning that we don't want to create a new variable, we just want to modify what we have "inplace"

# %%
gdf.to_crs("EPSG:4326", inplace=True)

# notice the change in the geometry of each point to a lat, lon value
gdf.geometry
# Out:
# 1553     POINT (-86.93917 31.42130)
# 1554     POINT (-87.09553 33.93727)
# 1555     POINT (-85.48885 32.61220)
# 1556     POINT (-87.06943 31.10684)
# 1557     POINT (-87.44507 33.04670)
#                    ...
# 3911    POINT (-109.83501 42.68342)
# 3912    POINT (-104.73931 42.28081)
# 3913    POINT (-105.51799 44.47647)
# 3914    POINT (-110.98552 41.29704)
# 3915    POINT (-110.55214 41.79044)
# Name: geometry, Length: 2363, dtype: geometry

# %%
gdf
# Out:
#      region_name  tech_id             tech_name  unit_size_mw        xcoord  \
# 1553     alabama        4  coal_conv_pul_wo_ccs         600.0  8.569472e+05
# 1554     alabama        4  coal_conv_pul_wo_ccs         600.0  8.159472e+05
# 1555     alabama        4  coal_conv_pul_wo_ccs         600.0  9.789472e+05
# 1556     alabama        4  coal_conv_pul_wo_ccs         600.0  8.479472e+05
# 1557     alabama        4  coal_conv_pul_wo_ccs         600.0  7.929472e+05
# ...          ...      ...                   ...           ...           ...
# 3911     wyoming       17     solar_pv_non_dist          80.0 -1.123053e+06
# 3912     wyoming       18          wind_onshore         251.0 -7.150528e+05
# 3913     wyoming       18          wind_onshore         251.0 -7.540528e+05
# 3914     wyoming       18          wind_onshore         251.0 -1.240053e+06
# 3915     wyoming       18          wind_onshore         251.0 -1.196053e+06
#
# ...

# %%
# Out:
# Empty GeoDataFrame
# Columns: [region_name, tech_id, tech_name, unit_size_mw, xcoord, ycoord, index, buffer_in_km, sited_year, retirement_year, lmp_zone, locational_marginal_price_usd_per_mwh, generation_mwh_per_year, operating_cost_usd_per_year, net_operational_value_usd_per_year, interconnection_cost_usd_per_year, net_locational_cost_usd_per_year, capacity_factor_fraction, carbon_capture_rate_fraction, fuel_co2_content_tons_per_btu, fuel_price_usd_per_mmbtu, fuel_price_esc_rate_fraction, heat_rate_btu_per_kWh, lifetime_yrs, variable_om_usd_per_mwh, variable_om_esc_rate_fraction, carbon_tax_usd_per_ton, carbon_tax_esc_rate_fraction, geometry]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ## Here we go!

# %%
colorss=[[0,"9DC3E6"],[4,"F4B183"],[8,"AFABAB"],[9,"FFE699"],[13,"D993D9"],[15,"F4BFDB"],
            [16,"BAE5E2"],[17,"FF8B7D"],[18,"9BA4D6"]]

colorscale = ["9DC3E6","F4B183","AFABAB","FFE699","D993D9","F4BFDB","BAE5E2","FF8B7D","9BA4D6"]

# %%
fig = go.Figure(data=go.Scattergeo(
        lon = gdf.geometry.x,
        lat = gdf.geometry.y,
        marker = dict(
            color = gdf['tech_name'],
            reversescale = True,
            opacity = 0.7,
            size = 4,
            colorbar = dict(
                titleside = "right",
        )
    )
        ))

fig.update_layout(
        geo_scope='usa',
        
    )

fig.update_layout(
    title={
        'text': "Power Plant Distributions",
        'y':.88,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
    font = dict(
        family="Courier New",
        size=14,
        color="Black"
    ),
    geo_bgcolor='rgb(240,240,240)',
    showlegend = True
)

fig.update_geos(
    showcountries=True, countrycolor="Grey",
    showsubunits=True, subunitcolor="Grey",
    fitbounds="locations"
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 fig = go.Figure(data=go.Scattergeo(
#       2         lon = gdf.geometry.x,
#       3         lat = gdf.geometry.y,
#       4         marker = dict(
#       5             color = gdf['tech_name'],
#       6             reversescale = True,
#       7             opacity = 0.7,
#       8             size = 4,
#       9             colorbar = dict(
#      10                 titleside = "right",
#      11         )
#      12     )
#      13         ))
#      15 fig.update_layout(
#      16         geo_scope='usa',
#      17
#      18     )
#      20 fig.update_layout(
#      21     title={
#      22         'text': "Power Plant Distributions",
#    (...)
#      33     showlegend = True
#      34 )
#
# ...
